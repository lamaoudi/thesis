# %%
import json
import csv
import requests
import time

# %%
##coordinates for Kigali
latitude = "-2.2417996081589897,"

longitude = "29.800809309442215"

#Rwanda radius approx. 4x10^6 
#test radius of 2 km, 2000 m 
radius = "2500"
bus_type = "school"

api_key = ""

# %%
url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location='+latitude+longitude+'&radius='+radius+'&type='+bus_type+'&key='+api_key

# %%
print(url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=-2.2417996081589897,29.800809309442215&radius=2500&type=school&key=AIzaSyDBMfBqvsCYz151dNSAt_ixHn0XgPAkO84

# %%
headers = {'content_type':'application/json', 'User-Agent':'lamaoudi'}

# %%
def csv_write():
    csvfile = open('google_maps.csv', 'w')
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(["name", "type", "vicinity", "lat", "long"])

# %%
response = requests.get(url=url, headers=headers).json()
#writer = csv.writer(csvfile, delimiter=',')

# %%
with open('google_maps.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter = ",")
    
    writer.writerow(["name", "type", "lat", "long"])
    for obj in response['results']:
        writer.writerow([obj['name'],obj['types'],obj['vicinity'], obj['geometry']['location']['lat'],obj['geometry']['location']['lng']])
        
        while ('next_page_token' in response):
            url2 = url + '&pagetoken=' + response['next_page_token']
            time.sleep(5)
            response = requests.get(url=url2, headers=headers).json()
            for obj in response['results']:
                writer.writerow([obj['name'],obj['types'],obj['vicinity'], obj['geometry']['location']['lat'],obj['geometry']['location']['lng']])
                
        else:
            print(response)
            
    if __name__ == '__main__':
        csv_write()
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -2.2379856, 'lng': 29.7936461}, 'viewport': {'northeast': {'lat': -2.236496569708498, 'lng': 29.79494663029149}, 'southwest': {'lat': -2.239194530291502, 'lng': 29.7922486697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png', 'name': 'College de Bethel', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2448, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104300817492393940046">Hatunguramye Bosco</a>'], 'photo_reference': 'ATtYBwJ9z6QWfkwsjXVBM7utG70Mm_lzC93qrAj_xtDVht0UwBDr0riRK_QhvhhzK1Qu17irFVHIZ1p9CEwIMH0Np-kfRDbQU3xF7bigZ58vIWJHs5JWg-6ZCHyRyToL6EinpEiaEQlyv4D9UbTdo3H3dO8CYofDEeednquPCm3laTioO_Kk', 'width': 3264}], 'place_id': 'ChIJn5fZu9RJwxkR44rAq0YH38c', 'plus_code': {'compound_code': 'QQ6V+RF Ruhango, Rwanda', 'global_code': '6G9FQQ6V+RF'}, 'rating': 4, 'reference': 'ChIJn5fZu9RJwxkR44rAq0YH38c', 'sco
# ...

# %%
print(response)
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -1.946792900000001, 'lng': 30.0607081}, 'viewport': {'northeast': {'lat': -1.945422569708498, 'lng': 30.0620990802915}, 'southwest': {'lat': -1.948120530291502, 'lng': 30.0594011197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png', 'name': 'Urwego Bank', 'place_id': 'ChIJkTVonyak3BkRMmvw7JqK14s', 'plus_code': {'compound_code': '3336+77 Kigali, Rwanda', 'global_code': '6GCG3336+77'}, 'rating': 5, 'reference': 'ChIJkTVonyak3BkRMmvw7JqK14s', 'scope': 'GOOGLE', 'types': ['bank', 'finance', 'point_of_interest', 'establishment'], 'user_ratings_total': 1, 'vicinity': '2 KN 3 Avenue, Kigali'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -1.9464935, 'lng': 30.0604579}, 'viewport': {'northeast': {'lat': -1.945022519708498, 'lng': 30.0618054802915}, 'southwest': {'lat': -1.947720480291502, 'lng': 30.0591075197085}}}, 'icon': 'h
# ...

# %%
## approach is to move around with different coordinates and then remove duplicates and mask it to the admin boundary of Rwanda 
input_shp = ogr.Open(shape_file)
shp_layer = input_shp.GetLayer()

pixel_size = 0.1
xmin, xmax, ymin, ymax = shp_layer.GetExtent()

ds = gdal.Rasterize(output_raster, shape_file, xRes=pixel_size, yRes=pixel_size, 
                    burnValues=255, outputBounds=[xmin, ymin, xmax, ymax], 
                    outputType=gdal.GDT_Byte)
ds = None
